# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
X = [1, 3, 7, 13, 24]
y = [77, 21, 47, 87, 2]

# %%
plt.plot(y);

# %%
plt.plot(X, y);

# %%
fig, ax = plt.subplots()
ax.plot(X, y);

# %%
# 0 import matplotlib and git it ready for plotting in Jupyter

# Prepare Data
X = [7, 21, 42, 84, 100]
y = [3, 7, 14, 24, 35]

#2. Setup Plot
fig, ax = plt.subplots(figsize=(10, 7))

# 3. Plot Data
ax.plot(X,y)

#4 Customize plot 
ax.set(title='Simple Plot',
       xlabel='x-axis',
       ylabel='y-axis')

# 5. save and show
fig.savefig('review_one_ex1.png')

# %%
x = np.linspace(0, 10, 100)
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
foods = {'pizza': 7, 'cookies': 3, 'icecream': 5}

# %%
fig, ax = plt.subplots()
ax.bar(foods.keys(), foods.values());
ax.set(title='J\'s fav foods', 
       ylabel= '$Price');

# %%
fig, ax = plt.subplots()
ax.barh(list(foods.keys()), list(foods.values()));

# %%
ran_np = np.random.normal(21, 21, 1000)
# Out:
# array([ 30.46595523,  13.05397948, -13.32353645,  69.99985501,
#         38.96543586,  36.03506908,   5.15408554,  24.01003578,
#         16.46660287,  42.81537059])

# %%
fig, ax = plt.subplots()
ax.hist(ran_np);

# %%
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %%
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, 
                                             ncols=2,
                                             figsize=(10,5));

# %%
fig , ax = plt.subplots(nrows=2, 
                        ncols=2,
                        figsize=(10,5))

ax[0,0].plot(x, x/2)
ax[0,1].scatter(np.random.random(10), np.random.random(10))
ax[1,0].bar(foods.keys(), foods.values())
ax[1,1].hist(np.random.normal(77, 100, 1000));

# %%
car_sales = pd.read_csv('car_sales.csv')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales['Price'].str.replace('[\$\,]|\.\d*', '').astype(int)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales['Total sales'] = car_sales['Price'].cumsum()
car_sales['Sale Date'] = pd.date_range('6/5/2020', periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total sales  Sale Date
# 0  Toyota  White         150043      4   4000         4000 2020-06-05
# 1   Honda    Red          87899      4   5000         9000 2020-06-06
# 2  Toyota   Blue          32549      3   7000        16000 2020-06-07
# 3     BMW  Black          11179      5  22000        38000 2020-06-08
# 4  Nissan  White         213095      4   3500        41500 2020-06-09
# 5  Toyota  Green          99213      4   4500        46000 2020-06-10
# 6   Honda   Blue          45698      4   7500        53500 2020-06-11
# 7   Honda   Blue          54738      4   7000        60500 2020-06-12
# 8  Toyota  White          60000      4   6250        66750 2020-06-13
# 9  Nissan  White          31600      4   9700        76450 2020-06-14

# %%
fig, ax = plt.subplots()
ax.plot(car_sales['Sale Date'], car_sales['Total sales']);

# %%
car_sales['Price'] = car_sales['Price'].astype(int)

# %%
fig, ax = plt.subplots()

ax.scatter(car_sales['Odometer (KM)'], car_sales['Price']);

# %%
x = np.random.rand(10,4)
x

df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0  0.440584  0.230002  0.936799  0.878754
# 1  0.884749  0.323351  0.058238  0.998505
# 2  0.961777  0.378714  0.041698  0.722946
# 3  0.631126  0.974720  0.360243  0.758903
# 4  0.339401  0.328033  0.737520  0.098579
# 5  0.201866  0.037163  0.447519  0.266993
# 6  0.865224  0.934699  0.833992  0.199139
# 7  0.799914  0.239678  0.388795  0.982878
# 8  0.550928  0.206764  0.296003  0.415111
# 9  0.024276  0.076977  0.010797  0.161234

# %%
df.plot.bar();

# %%
fig, ax = plt.subplots()
ax.bar(car_sales['Make'], car_sales['Odometer (KM)']);

# %%
car_sales['Odometer (KM)'].hist();

# %%
car_sales['Odometer (KM)'].hist(bins=20);

# %%
heart = pd.read_csv('heart.csv')
heart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart['age'].hist(bins=50);

# %%
heart.plot.hist(figsize=(10,30), subplots=True);

# %%
# OO method from scratch
fig, ax = plt.subplots(figsize=(10,5))

over_50 = heart[heart['age'] >= 50]

#Plot the data
scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'])

# Customize the plot
ax.set(title='Heart Disease and Cholesterol Levels',
       xlabel='Age',
       ylabel='Cholesteral')

# Add a legend
ax.legend(*scatter.legend_elements(), title='Target');

# Add a horizontal line
ax.axhline(over_50['chol'].mean(), linestyle='--');

# %%
# OO method from scratch
plt.style.use('seaborn-whitegrid')
fig, ax = plt.subplots(figsize=(10,5))

over_50 = heart[heart['age'] >= 50]

#Plot the data
scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'],
                     cmap='winter')

# Customize the plot
ax.set(title='Heart Disease and Cholesterol Levels',
       xlabel='Age',
       ylabel='Cholesteral')

# Add a legend
ax.legend(*scatter.legend_elements(), title='Target');

# Add a horizontal line
ax.axhline(over_50['chol'].mean(), linestyle='--');

# %%
fig.savefig('heart_review1.png')
